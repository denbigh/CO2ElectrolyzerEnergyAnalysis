# %% [markdown]
# # Histogram Development

# %%
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
from scipy import optimize

from Electrolyzer_Model import MassBalance, ElectrolyzerCosting

from matplotlib import rc
import matplotlib.pylab as plt

rc('font', **{'family': 'serif', 'serif': ['Computer Modern'], 'size' : 22})
rc('text', usetex=True)

#ColorScheme = ['#7fc97f', '#beaed4', '#fdc086', '#ffff99', '#386cb0']
ColorSchemePastel = ['#66c2a5', '#fc8d62', '#8da0cb', '#e78ac3', '#a6d854']
ColorSchemePastel2 = ["#ff8aa2", "#ffb7b2", "#ffdac1", "#e2f0cb", "#B5eAD7", "#c7ceea"]
ColorScheme = ['#0072BD', '#D95319', '#EDB120', '#7E2F8E', '#77AC30', '#4DBEEE', '#A2142F']

import warnings
warnings.filterwarnings('ignore')

# %%
Optimal_SPC_vals_AB = np.loadtxt("Optimal_SPC_vals_AB.txt")
fig, ax = plt.subplots(figsize =(8, 6), dpi=300)
ax.hist(Optimal_SPC_vals_AB, bins = np.linspace(0, 0.17, 28), density=True)

plt.xlabel("Optimal Single Pass Conversion", fontsize = 24)
plt.ylabel("Probabiliy Density", fontsize = 24);
plt.xlim([0,0.2]);
ax.annotate("Second Law Efficiency: 5\% \n Maximum HER FE: 20\%", [.14,40], fontsize = 20,  verticalalignment='center', horizontalalignment='center')
plt.savefig("SPC_5_20.pdf")

# %%
Optimal_SPC_vals_AC = np.loadtxt("Optimal_SPC_vals_AC.txt")
fig, ax = plt.subplots(figsize =(8, 6), dpi=300)
ax.hist(Optimal_SPC_vals_AC, bins = np.linspace(0, 0.17, 28), density=True)

plt.xlabel("Optimal Single Pass Conversion", fontsize = 24)
plt.ylabel("Probabiliy Density", fontsize = 24);
plt.xlim([0,0.2]);
ax.annotate("Second Law Efficiency: 5\% \n Maximum HER FE: 10\%", [.14,33],  fontsize = 20, verticalalignment='center', horizontalalignment='center')
plt.savefig("SPC_5_10.pdf")

# %%
Optimal_SPC_vals_AD = np.loadtxt("Optimal_SPC_vals_AD.txt")
fig, ax = plt.subplots(figsize =(8, 6), dpi=300)
ax.hist(Optimal_SPC_vals_AD, bins = np.linspace(0, 0.17, 28), density=True)

plt.xlabel("Optimal Single Pass Conversion", fontsize = 24)
plt.ylabel("Probabiliy Density", fontsize = 24);
plt.xlim([0,0.2]);
ax.annotate("Second Law Efficiency: 5\% \n Maximum HER FE: 5\%", [.148,30], fontsize = 20, verticalalignment='center', horizontalalignment='center')
plt.savefig("SPC_5_5.pdf")

# %%
Optimal_SPC_vals_AE = np.loadtxt("Optimal_SPC_vals_AE.txt")
fig, ax = plt.subplots(figsize =(8, 6), dpi=300)
ax.hist(Optimal_SPC_vals_AE, bins = np.linspace(0, 0.17, 28), density=True)

plt.xlabel("Optimal Single Pass Conversion", fontsize = 24)
plt.ylabel("Probabiliy Density", fontsize = 24);
plt.xlim([0,0.2]);
ax.annotate("Second Law Efficiency: 10\% \n Maximum HER FE: 20\%", [.13,35], fontsize = 20, verticalalignment='center', horizontalalignment='center')
plt.savefig("SPC_10_20.pdf")

# %%
Optimal_SPC_vals_AF = np.loadtxt("Optimal_SPC_vals_AF.txt")
fig, ax = plt.subplots(figsize =(8, 6), dpi=300)
ax.hist(Optimal_SPC_vals_AF, bins = np.linspace(0, 0.17, 28), density=True)

plt.xlabel("Optimal Single Pass Conversion", fontsize = 24)
plt.ylabel("Probabiliy Density", fontsize = 24);
plt.xlim([0,0.2]);
ax.annotate("Second Law Efficiency: 10\% \n Maximum HER FE: 10\%", [.13,45], fontsize = 20, verticalalignment='center', horizontalalignment='center')
plt.savefig("SPC_10_10.pdf")

# %%
Optimal_SPC_vals_AG = np.loadtxt("Optimal_SPC_vals_AG.txt")
fig, ax = plt.subplots(figsize =(8, 6), dpi=300)
ax.hist(Optimal_SPC_vals_AG, bins = np.linspace(0, 0.17, 28), density=True)

plt.xlabel("Optimal Single Pass Conversion", fontsize = 24)
plt.ylabel("Probabiliy Density", fontsize = 24);
plt.xlim([0,0.2]);
ax.annotate("Second Law Efficiency: 10\% \n Maximum HER FE: 5\%", [.14,33], fontsize = 20, verticalalignment='center', horizontalalignment='center')
plt.savefig("SPC_10_5.pdf")

# %%
Optimal_SPC_vals_AH = np.loadtxt("Optimal_SPC_vals_AH.txt")
fig, ax = plt.subplots(figsize =(8, 6), dpi=300)
ax.hist(Optimal_SPC_vals_AH, bins = np.linspace(0, 0.17, 28), density=True)

plt.xlabel("Optimal Single Pass Conversion", fontsize = 24)
plt.ylabel("Probabiliy Density", fontsize = 24);
plt.xlim([0,0.2]);
ax.annotate("Second Law Efficiency: 20\% \n Maximum HER FE: 20\%", [.13,38], fontsize = 20, verticalalignment='center', horizontalalignment='center')
plt.savefig("SPC_20_20.pdf")

# %%
Optimal_SPC_vals_AI = np.loadtxt("Optimal_SPC_vals_AI.txt")
fig, ax = plt.subplots(figsize =(8, 6), dpi=300)
ax.hist(Optimal_SPC_vals_AI, bins = np.linspace(0, 0.17, 28), density=True)

plt.xlabel("Optimal Single Pass Conversion", fontsize = 24)
plt.ylabel("Probabiliy Density", fontsize = 24);
plt.xlim([0,0.2]);
ax.annotate("Second Law Efficiency: 20\% \n Maximum HER FE: 10\%", [.135,38], fontsize = 20, verticalalignment='center', horizontalalignment='center')
plt.savefig("SPC_20_10.pdf")

# %%
Optimal_SPC_vals_AJ = np.loadtxt("Optimal_SPC_vals_AJ.txt")
fig, ax = plt.subplots(figsize =(8, 6), dpi=300)
ax.hist(Optimal_SPC_vals_AJ, bins = np.linspace(0, 0.17, 28), density=True)

plt.xlabel("Optimal Single Pass Conversion", fontsize = 24)
plt.ylabel("Probabiliy Density", fontsize = 24);
plt.xlim([0,0.2]);
ax.annotate("Second Law Efficiency: 20\% \n Maximum HER FE: 5\%", [.14,32], fontsize = 20, verticalalignment='center', horizontalalignment='center')
plt.savefig("SPC_20_5.pdf")

# %% [markdown]
# # Single Pass Consumption Plots

# %%
Optimal_SPConsump_vals_AK = np.loadtxt("Optimal_SPConsump_vals_AK.txt")
fig, ax = plt.subplots(figsize =(8, 6), dpi=300)
ax.hist(Optimal_SPConsump_vals_AK, bins = np.linspace(0, 1, 28), density=True)

plt.xlabel("Optimal Single Pass Consumption", fontsize = 24)
plt.ylabel("Probabiliy Density", fontsize = 24);
plt.xlim([0,1]);
ax.annotate("Second Law Efficiency: 5\% \n Maximum HER FE: 20\%", [.7,9], fontsize = 20,  verticalalignment='center', horizontalalignment='center')
plt.savefig("SPConsump_5_20.pdf")

# %%
Optimal_SPConsump_vals_AL = np.loadtxt("Optimal_SPConsump_vals_AL.txt")
fig, ax = plt.subplots(figsize =(8, 6), dpi=300)
ax.hist(Optimal_SPConsump_vals_AL, bins = np.linspace(0, 1, 28), density=True)

plt.xlabel("Optimal Single Pass Consumption", fontsize = 24)
plt.ylabel("Probabiliy Density", fontsize = 24);
plt.xlim([0,1]);
ax.annotate("Second Law Efficiency: 5\% \n Maximum HER FE: 10\%", [.7,8], fontsize = 20,  verticalalignment='center', horizontalalignment='center')
plt.savefig("SPConsump_5_10.pdf")

# %%
Optimal_SPConsump_vals_AM = np.loadtxt("Optimal_SPConsump_vals_AM.txt")
fig, ax = plt.subplots(figsize =(8, 6), dpi=300)
ax.hist(Optimal_SPConsump_vals_AM, bins = np.linspace(0, 1, 28), density=True)

plt.xlabel("Optimal Single Pass Consumption", fontsize = 24)
plt.ylabel("Probabiliy Density", fontsize = 24);
plt.xlim([0,1]);
ax.annotate("Second Law Efficiency: 5\% \n Maximum HER FE: 5\%", [.73,5.5], fontsize = 20,  verticalalignment='center', horizontalalignment='center')
plt.savefig("SPConsump_5_5.pdf")

# %%
Optimal_SPConsump_vals_AN = np.loadtxt("Optimal_SPConsump_vals_AN.txt")
fig, ax = plt.subplots(figsize =(8, 6), dpi=300)
ax.hist(Optimal_SPConsump_vals_AN, bins = np.linspace(0, 1, 28), density=True)

plt.xlabel("Optimal Single Pass Consumption", fontsize = 24)
plt.ylabel("Probabiliy Density", fontsize = 24);
plt.xlim([0,1]);
ax.annotate("Second Law Efficiency: 10\% \n Maximum HER FE: 20\%", [.68,8.5], fontsize = 20,  verticalalignment='center', horizontalalignment='center')
plt.savefig("SPConsump_10_20.pdf")

# %%
Optimal_SPConsump_vals_AO = np.loadtxt("Optimal_SPConsump_vals_AO.txt")
fig, ax = plt.subplots(figsize =(8, 6), dpi=300)
ax.hist(Optimal_SPConsump_vals_AO, bins = np.linspace(0, 1, 28), density=True)

plt.xlabel("Optimal Single Pass Consumption", fontsize = 24)
plt.ylabel("Probabiliy Density", fontsize = 24);
plt.xlim([0,1]);
ax.annotate("Second Law Efficiency: 10\% \n Maximum HER FE: 10\%", [.68,8.5], fontsize = 20,  verticalalignment='center', horizontalalignment='center')
plt.savefig("SPConsump_10_10.pdf")

# %%
Optimal_SPConsump_vals_AP = np.loadtxt("Optimal_SPConsump_vals_AP.txt")
fig, ax = plt.subplots(figsize =(8, 6), dpi=300)
ax.hist(Optimal_SPConsump_vals_AP, bins = np.linspace(0, 1, 28), density=True)

plt.xlabel("Optimal Single Pass Consumption", fontsize = 24)
plt.ylabel("Probabiliy Density", fontsize = 24);
plt.xlim([0,1]);
ax.annotate("Second Law Efficiency: 10\% \n Maximum HER FE: 5\%", [.68,7], fontsize = 20,  verticalalignment='center', horizontalalignment='center')
plt.savefig("SPConsump_10_5.pdf")

# %%
Optimal_SPConsump_vals_AQ = np.loadtxt("Optimal_SPConsump_vals_AQ.txt")
fig, ax = plt.subplots(figsize =(8, 6), dpi=300)
ax.hist(Optimal_SPConsump_vals_AQ, bins = np.linspace(0, 1, 28), density=True)

plt.xlabel("Optimal Single Pass Consumption", fontsize = 24)
plt.ylabel("Probabiliy Density", fontsize = 24);
plt.xlim([0,1]);
ax.annotate("Second Law Efficiency: 20\% \n Maximum HER FE: 20\%", [.68,8], fontsize = 20,  verticalalignment='center', horizontalalignment='center')
plt.savefig("SPConsump_20_20.pdf")

# %%
Optimal_SPConsump_vals_AR = np.loadtxt("Optimal_SPConsump_vals_AR.txt")
fig, ax = plt.subplots(figsize =(8, 6), dpi=300)
ax.hist(Optimal_SPConsump_vals_AR, bins = np.linspace(0, 1, 28), density=True)

plt.xlabel("Optimal Single Pass Consumption", fontsize = 24)
plt.ylabel("Probabiliy Density", fontsize = 24);
plt.xlim([0,1]);
ax.annotate("Second Law Efficiency: 20\% \n Maximum HER FE: 10\%", [.68,8], fontsize = 20,  verticalalignment='center', horizontalalignment='center')
plt.savefig("SPConsump_20_10.pdf")

# %%
Optimal_SPConsump_vals_AS = np.loadtxt("Optimal_SPConsump_vals_AS.txt")
fig, ax = plt.subplots(figsize =(8, 6), dpi=300)
ax.hist(Optimal_SPConsump_vals_AS, bins = np.linspace(0, 1, 28), density=True)

plt.xlabel("Optimal Single Pass Consumption", fontsize = 24)
plt.ylabel("Probabiliy Density", fontsize = 24);
plt.xlim([0,1]);
ax.annotate("Second Law Efficiency: 20\% \n Maximum HER FE: 5\%", [.68,8], fontsize = 20,  verticalalignment='center', horizontalalignment='center')
plt.savefig("SPConsump_20_5.pdf")
